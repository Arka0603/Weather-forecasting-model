# %%
import pandas as pd

# %%
weather=pd.read_csv("local_weather.csv", index_col="DATE")

# %%
weather
# Out:
#                 STATION                 NAME  LATITUDE  LONGITUDE  ELEVATION  \
# DATE
# 2023-01-01  IN022023000  NEW DELHI PALAM, IN    28.567     77.117      233.0
# 2023-01-02  IN022023000  NEW DELHI PALAM, IN    28.567     77.117      233.0
# 2023-01-03  IN022023000  NEW DELHI PALAM, IN    28.567     77.117      233.0
# 2023-01-04  IN022023000  NEW DELHI PALAM, IN    28.567     77.117      233.0
# 2023-01-05  IN022023000  NEW DELHI PALAM, IN    28.567     77.117      233.0
# ...                 ...                  ...       ...        ...        ...
# 2023-04-08  IN022023000  NEW DELHI PALAM, IN    28.567     77.117      233.0
# 2023-04-09  IN022023000  NEW DELHI PALAM, IN    28.567     77.117      233.0
# 2023-04-10  IN022023000  NEW DELHI PALAM, IN    28.567     77.117      233.0
# 2023-04-11  IN022023000  NEW DELHI PALAM, IN    28.567     77.117      233.0
# 2023-04-12  IN022023000  NEW DELHI PALAM, IN    28.567     77.117      233.0
#
#             PRCP PRCP_ATTRIBUTES  TAVG TAVG_ATTRIBUTES  TMAX TMAX_ATTRIBUTES  \
# DATE
# 2023-01-01   NaN             NaN    56            H,,S  67.0             ,,S
# 2023-01-02   NaN             NaN    54            H,,S  67.0             ,,S
# 2023-01-03   NaN             NaN    52            H,,S  64.0             ,,S
# 2023-01-04   NaN             NaN    49            H,,S  59.0             ,,S
# 2023-01-05   NaN             NaN    48            H,,S  57.0             ,,S
# ...          ...             ...   ...             ...   ...             ...
# 2023-04-08   NaN             NaN    80            H,,S  93.0             ,,S
# 2023-04-09   NaN             NaN    82            H,,S  96.0             ,,S
# 2023-04-10   NaN             NaN    82            H,,S  95.0             ,,S
# 2023-04-11   NaN             NaN    84            H,,S  98.0             ,,S
# 2023-04-12   NaN             NaN    86            H,,S  98.0             ,,S
#
#             TMIN TMIN_ATTRIBUTES
# DATE
# 2023-01-01  48.0             ,,S
# 2023-01-02   NaN             NaN
# 2023-01-03   NaN             NaN
# 2023-01-04   NaN             NaN
# 2023-01-05  43.0             ,,S
# ...          ...             ...
# 2023-04-08  64.0             ,,S
# 2023-04-09  67.0             ,,S
# 2023-04-10  67.0             ,,S
# 2023-04-11  68.0             ,,S
# 2023-04-12   NaN             NaN
#
# [102 rows x 13 columns]

# %%
weather.apply(pd.isnull).sum()/weather.shape[0]
# Out:
# STATION            0.000000
# NAME               0.000000
# LATITUDE           0.000000
# LONGITUDE          0.000000
# ELEVATION          0.000000
# PRCP               0.862745
# PRCP_ATTRIBUTES    0.862745
# TAVG               0.000000
# TAVG_ATTRIBUTES    0.000000
# TMAX               0.127451
# TMAX_ATTRIBUTES    0.127451
# TMIN               0.490196
# TMIN_ATTRIBUTES    0.490196
# dtype: float64

# %%
core_weather = weather[["PRCP",  "TMAX", "TMIN"]].copy()
core_weather.columns = ["precip", "temp_max", "temp_min"]

# %%
core_weather.apply(pd.isnull).sum()
# Out:
# precip      88
# temp_max    13
# temp_min    50
# dtype: int64

# %%
core_weather[pd.isnull(core_weather["precip"])]
# Out:
#             precip  temp_max  temp_min
# DATE
# 2023-01-01     NaN      67.0      48.0
# 2023-01-02     NaN      67.0       NaN
# 2023-01-03     NaN      64.0       NaN
# 2023-01-04     NaN      59.0       NaN
# 2023-01-05     NaN      57.0      43.0
# ...            ...       ...       ...
# 2023-04-08     NaN      93.0      64.0
# 2023-04-09     NaN      96.0      67.0
# 2023-04-10     NaN      95.0      67.0
# 2023-04-11     NaN      98.0      68.0
# 2023-04-12     NaN      98.0       NaN
#
# [88 rows x 3 columns]

# %%
core_weather.loc["2023-02-15",:]
# Out:
# precip     NaN
# temp_max   NaN
# temp_min   NaN
# Name: 2023-02-15, dtype: float64

# %%
core_weather["precip"].value_counts() / core_weather.shape[0]
# Out:
# 0.00    0.058824
# 0.01    0.019608
# 1.02    0.009804
# 0.04    0.009804
# 0.20    0.009804
# 1.18    0.009804
# 0.63    0.009804
# 0.59    0.009804
# Name: precip, dtype: float64

# %%
core_weather["precip"] = core_weather["precip"].fillna(0)

# %%
core_weather.apply(pd.isnull).sum()
# Out:
# precip       0
# temp_max    13
# temp_min    50
# dtype: int64

# %%
core_weather[pd.isnull(core_weather["temp_min"])]
# Out:
#             precip  temp_max  temp_min
# DATE
# 2023-01-02    0.00      67.0       NaN
# 2023-01-03    0.00      64.0       NaN
# 2023-01-04    0.00      59.0       NaN
# 2023-01-06    0.00       NaN       NaN
# 2023-01-07    0.00       NaN       NaN
# 2023-01-10    0.00       NaN       NaN
# 2023-01-13    0.00      70.0       NaN
# 2023-01-14    0.00      69.0       NaN
# 2023-01-15    0.00      63.0       NaN
# 2023-01-16    0.00      64.0       NaN
# 2023-01-20    0.00      73.0       NaN
# 2023-01-22    0.00      73.0       NaN
# 2023-01-23    0.00      77.0       NaN
# 2023-01-24    0.00      77.0       NaN
# 2023-01-25    0.00      69.0       NaN
# 2023-01-26    0.00      67.0       NaN
# 2023-01-27    0.00      68.0       NaN
# 2023-01-28    0.00      73.0       NaN
# 2023-01-31    0.00      67.0       NaN
# 2023-02-03    0.00      74.0       NaN
# 2023-02-04    0.00      76.0       NaN
# 2023-02-05    0.00       NaN       NaN
# 2023-02-07    0.00       NaN       NaN
# 2023-02-08    0.00      76.0       NaN
# 2023-02-09    0.00       NaN       NaN
# 2023-02-10    0.00      84.0       NaN
# 2023-02-11    0.00      84.0       NaN
# 2023-02-12    0.00      80.0       NaN
# 2023-02-13    0.00      73.0       NaN
# 2023-02-15    0.00       NaN       NaN
# 2023-02-17    0.00      83.0       NaN
# 2023-02-18    0.00      83.0       NaN
# 2023-02-20    0.00       NaN       NaN
# 2023-02-21    0.00      90.0       NaN
# 2023-02-22    0.00      85.0       NaN
# 2023-02-25    0.00      85.0       NaN
# 2023-03-03    0.00      88.0       NaN
# 2023-03-09    0.00      87.0       NaN
# 2023-03-11    0.00      90.0       NaN
# 2023-03-12    0.00      92.0       NaN
# 2023-03-16    0.00      93.0       NaN
# 2023-03-17    0.00      85.0       NaN
# 2023-03-18    0.04      85.0       NaN
# 2023-03-19    0.20      81.0       NaN
# 2023-03-20    1.18      81.0       NaN
# 2023-03-24    0.00      86.0       NaN
# 2023-03-25    0.59      84.0       NaN
# 2023-03-30    0.00      91.0       NaN
# 2023-03-31    0.00      79.0       NaN
# 2023-04-12    0.00      98.0       NaN

# %%
core_weather.loc["2023-01-18":"2023-01-28"]
# Out:
#             precip  temp_max  temp_min
# DATE
# 2023-01-18     0.0      65.0      43.0
# 2023-01-19     0.0      70.0      48.0
# 2023-01-20     0.0      73.0       NaN
# 2023-01-21     0.0      73.0      50.0
# 2023-01-22     0.0      73.0       NaN
# 2023-01-23     0.0      77.0       NaN
# 2023-01-24     0.0      77.0       NaN
# 2023-01-25     0.0      69.0       NaN
# 2023-01-26     0.0      67.0       NaN
# 2023-01-27     0.0      68.0       NaN
# 2023-01-28     0.0      73.0       NaN

# %%
core_weather = core_weather.fillna(method="ffill")

# %%
core_weather.apply(pd.isnull).sum()
# Out:
# precip      0
# temp_max    0
# temp_min    0
# dtype: int64

# %%
# Check for missing value defined in data documentation
core_weather.apply(lambda x: (x == 9999).sum())
# Out:
# precip      0
# temp_max    0
# temp_min    0
# dtype: int64

# %%
core_weather.dtypes
# Out:
# precip      float64
# temp_max    float64
# temp_min    float64
# dtype: object

# %%
core_weather.index
# Out:
# Index(['2023-01-01', '2023-01-02', '2023-01-03', '2023-01-04', '2023-01-05',
#        '2023-01-06', '2023-01-07', '2023-01-08', '2023-01-09', '2023-01-10',
#        ...
#        '2023-04-03', '2023-04-04', '2023-04-05', '2023-04-06', '2023-04-07',
#        '2023-04-08', '2023-04-09', '2023-04-10', '2023-04-11', '2023-04-12'],
#       dtype='object', name='DATE', length=102)

# %%
core_weather.index = pd.to_datetime(core_weather.index)

# %%
core_weather.index
# Out:
# DatetimeIndex(['2023-01-01', '2023-01-02', '2023-01-03', '2023-01-04',
#                '2023-01-05', '2023-01-06', '2023-01-07', '2023-01-08',
#                '2023-01-09', '2023-01-10',
#                ...
#                '2023-04-03', '2023-04-04', '2023-04-05', '2023-04-06',
#                '2023-04-07', '2023-04-08', '2023-04-09', '2023-04-10',
#                '2023-04-11', '2023-04-12'],
#               dtype='datetime64[ns]', name='DATE', length=102, freq=None)

# %%
core_weather.index.year
# Out:
# Int64Index([2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023,
#             ...
#             2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023],
#            dtype='int64', name='DATE', length=102)

# %%
core_weather[["temp_max", "temp_min"]].plot()
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
core_weather.index.year.value_counts().sort_index()
# Out:
# 2023    102
# Name: DATE, dtype: int64

# %%
core_weather["precip"].plot()
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
core_weather["target"] = core_weather.shift(-1)["temp_max"]

# %%
core_weather
# Out:
#             precip  temp_max  temp_min  target
# DATE
# 2023-01-01     0.0      67.0      48.0    67.0
# 2023-01-02     0.0      67.0      48.0    64.0
# 2023-01-03     0.0      64.0      48.0    59.0
# 2023-01-04     0.0      59.0      48.0    57.0
# 2023-01-05     0.0      57.0      43.0    57.0
# ...            ...       ...       ...     ...
# 2023-04-08     0.0      93.0      64.0    96.0
# 2023-04-09     0.0      96.0      67.0    95.0
# 2023-04-10     0.0      95.0      67.0    98.0
# 2023-04-11     0.0      98.0      68.0    98.0
# 2023-04-12     0.0      98.0      68.0     NaN
#
# [102 rows x 4 columns]

# %%
core_weather = core_weather.iloc[:-1,:].copy()

# %%
core_weather
# Out:
#             precip  temp_max  temp_min  target
# DATE
# 2023-01-01     0.0      67.0      48.0    67.0
# 2023-01-02     0.0      67.0      48.0    64.0
# 2023-01-03     0.0      64.0      48.0    59.0
# 2023-01-04     0.0      59.0      48.0    57.0
# 2023-01-05     0.0      57.0      43.0    57.0
# ...            ...       ...       ...     ...
# 2023-04-07     0.0      92.0      68.0    93.0
# 2023-04-08     0.0      93.0      64.0    96.0
# 2023-04-09     0.0      96.0      67.0    95.0
# 2023-04-10     0.0      95.0      67.0    98.0
# 2023-04-11     0.0      98.0      68.0    98.0
#
# [101 rows x 4 columns]

# %%
from sklearn.linear_model import Ridge

reg = Ridge(alpha=.1)

# %%
predictors = ["precip", "temp_max", "temp_min"]

# %%
train = core_weather.loc[:"2023-03-06"]
test = core_weather.loc["2023-03-07":]

# %%
train
# Out:
#             precip  temp_max  temp_min  target
# DATE
# 2023-01-01    0.00      67.0      48.0    67.0
# 2023-01-02    0.00      67.0      48.0    64.0
# 2023-01-03    0.00      64.0      48.0    59.0
# 2023-01-04    0.00      59.0      48.0    57.0
# 2023-01-05    0.00      57.0      43.0    57.0
# ...            ...       ...       ...     ...
# 2023-03-02    0.01      87.0      63.0    88.0
# 2023-03-03    0.00      88.0      63.0    88.0
# 2023-03-04    0.00      88.0      63.0    86.0
# 2023-03-05    0.00      86.0      63.0    86.0
# 2023-03-06    0.00      86.0      63.0    87.0
#
# [65 rows x 4 columns]

# %%
test
# Out:
#             precip  temp_max  temp_min  target
# DATE
# 2023-03-07    0.00      87.0      63.0    87.0
# 2023-03-08    0.00      87.0      63.0    87.0
# 2023-03-09    0.00      87.0      63.0    87.0
# 2023-03-10    0.00      87.0      64.0    90.0
# 2023-03-11    0.00      90.0      64.0    92.0
# 2023-03-12    0.00      92.0      64.0    92.0
# 2023-03-13    0.00      92.0      67.0    91.0
# 2023-03-14    0.00      91.0      67.0    93.0
# 2023-03-15    0.00      93.0      67.0    93.0
# 2023-03-16    0.00      93.0      67.0    85.0
# 2023-03-17    0.00      85.0      67.0    85.0
# 2023-03-18    0.04      85.0      67.0    81.0
# 2023-03-19    0.20      81.0      67.0    81.0
# 2023-03-20    1.18      81.0      67.0    79.0
# 2023-03-21    0.63      79.0      60.0    79.0
# 2023-03-22    0.00      79.0      62.0    86.0
# 2023-03-23    0.00      86.0      62.0    86.0
# 2023-03-24    0.00      86.0      62.0    84.0
# 2023-03-25    0.59      84.0      62.0    87.0
# 2023-03-26    0.00      87.0      64.0    84.0
# 2023-03-27    0.00      84.0      64.0    88.0
# 2023-03-28    0.00      88.0      64.0    91.0
# 2023-03-29    0.00      91.0      67.0    91.0
# 2023-03-30    0.00      91.0      67.0    79.0
# 2023-03-31    0.00      79.0      67.0    82.0
# 2023-04-01    0.00      82.0      62.0    86.0
# 2023-04-02    0.00      86.0      63.0    89.0
# 2023-04-03    0.00      89.0      67.0    89.0
# 2023-04-04    0.00      89.0      66.0    90.0
# 2023-04-05    0.00      90.0      65.0    92.0
# 2023-04-06    0.00      92.0      67.0    92.0
# 2023-04-07    0.00      92.0      68.0    93.0
# 2023-04-08    0.00      93.0      64.0    96.0
# 2023-04-09    0.00      96.0      67.0    95.0
# 2023-04-10    0.00      95.0      67.0    98.0
# 2023-04-11    0.00      98.0      68.0    98.0

# %%
reg.fit(train[predictors], train["target"])
# Out:
# Ridge(alpha=0.1)

# %%
predictions = reg.predict(test[predictors])

# %%
from sklearn.metrics import mean_squared_error

mean_squared_error(test["target"], predictions)
# Out:
# 11.321209687042359

# %%
combined = pd.concat([test["target"], pd.Series(predictions, index=test.index)], axis=1)
combined.columns = ["actual", "predictions"]

# %%
combined
# Out:
#             actual  predictions
# DATE
# 2023-03-07    87.0    86.609630
# 2023-03-08    87.0    86.609630
# 2023-03-09    87.0    86.609630
# 2023-03-10    90.0    86.607988
# 2023-03-11    92.0    89.444974
# 2023-03-12    92.0    91.336299
# 2023-03-13    91.0    91.331372
# 2023-03-14    93.0    90.385710
# 2023-03-15    93.0    92.277034
# 2023-03-16    85.0    92.277034
# 2023-03-17    85.0    84.711737
# 2023-03-18    81.0    84.755181
# 2023-03-19    81.0    81.146311
# 2023-03-20    79.0    82.210702
# 2023-03-21    79.0    79.733512
# 2023-03-22    86.0    79.045975
# 2023-03-23    86.0    85.665611
# 2023-03-24    84.0    85.665611
# 2023-03-25    87.0    84.415093
# 2023-03-26    84.0    86.607988
# 2023-03-27    88.0    83.771002
# 2023-03-28    91.0    87.553650
# 2023-03-29    91.0    90.385710
# 2023-03-30    79.0    90.385710
# 2023-03-31    82.0    79.037764
# 2023-04-01    86.0    81.882962
# 2023-04-02    89.0    85.663968
# 2023-04-03    89.0    88.494385
# 2023-04-04    90.0    88.496028
# 2023-04-05    92.0    89.443332
# 2023-04-06    92.0    91.331372
# 2023-04-07    93.0    91.329729
# 2023-04-08    96.0    92.281961
# 2023-04-09    95.0    95.114020
# 2023-04-10    98.0    94.168358
# 2023-04-11    98.0    97.003702

# %%
combined.plot()
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
reg.coef_
# Out:
# array([ 1.08611356,  0.94566216, -0.00164233])

# %%
core_weather["month_max"] = core_weather["temp_max"].rolling(30).mean()

core_weather["month_day_max"] = core_weather["month_max"] / core_weather["temp_max"]

core_weather["max_min"] = core_weather["temp_max"] / core_weather["temp_min"]

# %%
core_weather = core_weather.iloc[30:,:].copy()

# %%
def create_predictions(predictors, core_weather, reg):
    train = core_weather.loc[:"2023-03-06"]
    test = core_weather.loc["2023-03-07":]

    reg.fit(train[predictors], train["target"])
    predictions = reg.predict(test[predictors])

    error = mean_squared_error(test["target"], predictions)
    
    combined = pd.concat([test["target"], pd.Series(predictions, index=test.index)], axis=1)
    combined.columns = ["actual", "predictions"]
    return error, combined

# %%
predictors = ["precip", "temp_max", "temp_min", "month_day_max", "max_min"]

error, combined = create_predictions(predictors, core_weather, reg)
error
# Out:
# 11.196837891599651

# %%
combined.plot()
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
core_weather["monthly_avg"] = core_weather["temp_max"].groupby(core_weather.index.month).apply(lambda x: x.expanding(1).mean())
core_weather["day_of_year_avg"] = core_weather["temp_max"].groupby(core_weather.index.day_of_year).apply(lambda x: x.expanding(1).mean())

# %%
error, combined = create_predictions(predictors + ["monthly_avg", "day_of_year_avg"], core_weather, reg)
error
# Out:
# 11.290493486549218

# %%
reg.coef_
# Out:
# array([ 0.17267579,  0.32801303, -0.01347949,  4.1220768 ,  0.05522302,
#         0.21283539,  0.32801303])

# %%
core_weather.corr()["target"]
# Out:
# precip            -0.153090
# temp_max           0.858463
# temp_min           0.690387
# target             1.000000
# month_max          0.677250
# month_day_max     -0.110007
# max_min           -0.078631
# monthly_avg        0.721204
# day_of_year_avg    0.858463
# Name: target, dtype: float64

# %%
combined["diff"] = (combined["actual"] - combined["predictions"]).abs()

# %%
combined.sort_values("diff", ascending=False).head(10)
# Out:
#             actual  predictions       diff
# DATE
# 2023-03-30    79.0    90.204619  11.204619
# 2023-03-16    85.0    91.828624   6.828624
# 2023-03-18    81.0    86.875993   5.875993
# 2023-03-20    79.0    84.493147   5.493147
# 2023-04-10    98.0    93.454519   4.545481
# 2023-03-21    79.0    83.198332   4.198332
# 2023-04-08    96.0    91.974636   4.025364
# 2023-03-26    84.0    87.743710   3.743710
# 2023-03-19    81.0    84.400689   3.400689
# 2023-03-24    84.0    87.178966   3.178966
